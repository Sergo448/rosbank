# %%
import pandas as pd

# path to csv's files
path_to_history_prices = '..//csv_s//history_prices.csv'
path_to_investment_currencyhistory = '..//csv_s//investment_currencyhistory.csv'
path_to_securities = '..//csv_s//securities.csv'
path_to_сlients = '..//csv_s//history_prices.csv'

# read files
history_prices = pd.read_csv(path_to_history_prices)
investment_currencyhistory = pd.read_csv(path_to_investment_currencyhistory) 
securities = pd.read_csv(path_to_securities) 
сlients = pd.read_csv(path_to_сlients)

# drop column
history_prices = history_prices.drop(columns=['Unnamed: 0'])
investment_currencyhistory = investment_currencyhistory.drop(columns=['Unnamed: 0'])
securities = securities.drop(columns=['Unnamed: 0'])
securities['client_date'] = pd.to_datetime(securities['client_date'], format='%Y-%m-%d')

сlients = сlients.drop(columns=['Unnamed: 0'])

securities['client_date'] = pd.to_datetime(securities['client_date'],
                                                          format='%Y-%m-%d')
securities['client_date'] = securities['client_date'].dt.strftime('%Y-%m-%d')

# %%
securities
# Out:
#      operation_id  client_id client_date client_isin_paper  client_n_papers  \
# 0             455          3  2023-01-17            fdsfaw               46
# 1             553          5  2023-02-25         fjwj4nfu4               10
# 2            5807          4  2023-01-21            gdhf72              390
# 3            3855          6  2023-03-16           dcw12l1              487
# 4            1358          1  2023-03-10           dcw12l1               72
# ..            ...        ...         ...               ...              ...
# 151          4373          9  2023-02-26           f3bfic3              478
# 152          2594          9  2023-01-10              11dd              138
# 153          3395          3  2023-02-13         fjwj4nfu4              282
# 154          1475          9  2023-02-16           dcw12l1              134
# 155          6499          9  2023-01-03         fjwj4nfu4              177
#
#     client_currency client_rialto  client_closing_price
# 0               RUB           LON                 49426
# 1               AUD           GON                417761
# 2               AUD           LON                203273
# 3               RUB           BER                186051
# 4               RUB           NYC                407353
# ..              ...           ...                   ...
# 151             USD           MSK                 61882
# 152             RUB           NYC                349530
# 153             EUR           MSK                112996
# 154             EUR           GON                  9668
# 155             USD           SPD                 45568
#
# [156 rows x 8 columns]

# %%
securities = securities.sort_values(by=['client_id', 'client_date']).reset_index(drop=True, inplace=False)

# %%
securities
# Out:
#      operation_id  client_id client_date client_isin_paper  client_n_papers  \
# 0             811          1  2023-01-05          dwwdsxw1              452
# 1            6004          1  2023-01-08         fjwj4nfu4              137
# 2            3555          1  2023-01-19           ldoddd3              400
# 3            4696          1  2023-01-29         fmdkwm1e1              215
# 4            4860          1  2023-02-09            3kj3j3              394
# ..            ...        ...         ...               ...              ...
# 151           158         10  2023-03-07            fdsfaw              279
# 152          6143         10  2023-03-11           dcw12l1              374
# 153           156         10  2023-03-15            fjdh22              352
# 154          5068         10  2023-03-19             5673d              188
# 155          4818         10  2023-03-22         defdjwkf3              315
#
#     client_currency client_rialto  client_closing_price
# 0               EUR           BER                403389
# 1               RUB           LON                467368
# 2               RUB           SPD                195477
# 3               USD           MSK                 12624
# 4               AUD           MSK                 12619
# ..              ...           ...                   ...
# 151             EUR           SPD                256324
# 152             RUB           MSK                459934
# 153             RUB           MSK                452285
# 154             USD           NYC                248242
# 155             RUB           BER                417284
#
# [156 rows x 8 columns]

# %%
securities.client_id.nunique()
# Out:
# 10

# %%
"""
10 различных клиентов.

Выберем всю информацию по клиенту №1
"""

client_1 = securities.copy()
client_1 = client_1.drop(columns=['operation_id'])
client_1 = client_1.loc[client_1['client_id'] == 1]

# %%
from matplotlib import patheffects
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns; sns.set();
import numpy as np

# %%
client_1
# Out:
#     client_id client_date client_isin_paper  client_n_papers client_currency  \
# 0           1  2023-01-05          dwwdsxw1              452             EUR
# 1           1  2023-01-08         fjwj4nfu4              137             RUB
# 2           1  2023-01-19           ldoddd3              400             RUB
# 3           1  2023-01-29         fmdkwm1e1              215             USD
# 4           1  2023-02-09            3kj3j3              394             AUD
# 5           1  2023-02-23         defdjwkf3              423             AUD
# 6           1  2023-03-03         fjwj4nfu4              483             USD
# 7           1  2023-03-10           dcw12l1               72             RUB
# 8           1  2023-03-12             5673d               80             EUR
# 9           1  2023-03-16           dcw12l1              458             USD
# 10          1  2023-03-19         fjwj4nfu4               51             RUB
# 11          1  2023-03-20            fjdh22              242             AUD
# 12          1  2023-03-28           ldoddd3              173             AUD
#
#    client_rialto  client_closing_price
# 0            BER                403389
# 1            LON                467368
# 2            SPD                195477
# 3            MSK                 12624
# 4            MSK                 12619
# 5            GON                364425
# 6            NYC                445449
# 7            NYC                407353
# 8            MSK                286222
# 9            MSK                150716
# 10           LON                360271
# 11           NYC                223992
# 12           LON                 14737

# %%
list_of_unique_isin = client_1['client_isin_paper'].unique().tolist()
list_of_unique_isin
# Out:
# ['dwwdsxw1',
#  'fjwj4nfu4',
#  'ldoddd3',
#  'fmdkwm1e1',
#  '3kj3j3',
#  'defdjwkf3',
#  'dcw12l1',
#  '5673d',
#  'fjdh22']

# %%
fig, ax = plt.subplots(figsize=(16, 6))


ax.plot(client_1['client_date'],
        client_1['client_n_papers'],
        label="date_to_n_papers",
        # path_effects=[patheffects.withTickedStroke()],
        marker = '*',
       )
# Trend
#calculate equation for quadratic trendline
xn = len(client_1['client_date'])
x = np.arange(0, xn)
y = client_1['client_n_papers']
z = np.polyfit (x, y, 4)
p = np.poly1d (z)
ax.plot(x ,p(x), "r--")

ax.grid(which='major',
        color = 'k', 
        linewidth = 0.5)
ax.grid(which='minor', 
        color = 'k', 
        linestyle = ':')

plt.title('date_to_n_papers',size=16)
plt.xlabel('Dates', fontsize=14, fontweight="bold")
plt.ylabel("clients_n_papers", fontsize=14, fontweight="bold")
plt.xticks(rotation=45)
ax.legend(['plot', 'trend'])

plt.show();

# %%
fig, ax = plt.subplots(figsize=(16, 6))


ax.plot(client_1['client_date'],
        client_1['client_closing_price'],
        label="date_to_n_papers",
        # path_effects=[patheffects.withTickedStroke()],
        marker = '*',
       )

# Trend
#calculate equation for quadratic trendline
xn = len(client_1['client_date'])
x = np.arange(0, xn)
y = client_1['client_closing_price']
z = np.polyfit (x, y, 3)
p = np.poly1d (z)
ax.plot(x ,p(x), "r--")

ax.grid(which='major',
        color = 'k', 
        linewidth = 0.5)
ax.grid(which='minor', 
        color = 'k', 
        linestyle = ':')

plt.title('date_to_clos_price',size=16)
plt.xlabel('Dates', fontsize=14, fontweight="bold")
plt.ylabel("clients_n_papers", fontsize=14, fontweight="bold")
plt.xticks(rotation=45)
ax.legend(['plot', 'trend'])

plt.show();
